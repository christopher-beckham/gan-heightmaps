# %% [markdown]
# Download the h5 file from here: https://mega.nz/#!VfpRwD4Q!LlP1ln1tpcrzUByampJTg-OI6y7Myj2Vqx96BNLTTWA

# %%
DATASET_URL = "/Volumes/CB_RESEARCH/nasa/textures_v2_brown500_with_valid.h5"

# %%
# put your url here
#DATASET_URL = ""

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
h5 = h5py.File(DATASET_URL, "r")

# %%
h5.keys()
# Out:
# [u'xt', u'xv', u'yt', u'yv']

# %% [markdown]
# Show a random (heightmap,texture) pair

# %%
rnd_idx = np.random.randint(0, h5['xt'].shape[0])
plt.subplot(1,2,1)
plt.imshow(h5['xt'][rnd_idx][:,:,0],cmap="gray")
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(h5['yt'][rnd_idx],cmap="gray")
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)
